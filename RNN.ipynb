# %%
# Multivariate Time Series Forecasting

## Step 1: Dataset Selection and Loading

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler

import wandb
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Checking for GPU availability
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Setting seed for repeatability
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # Ensuring deterministic behavior for CUDA operations
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Out:
# Using device: cuda:0

# %%
# Initialize W&B project
wandb.init(project="RNN", entity="usf-alpha-neurons",config={
    'input_size': 2,  # Number of features (TMAX, RHAV)
    'hidden_size': 64,  # Size of hidden layer in RNN
    'output_size': 1,  # Predicting temperature (TMAX)
    'num_epochs': 10,  # Number of epochs for training
    'learning_rate': 0.001  # Learning rate
})
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sumit141 (usf-alpha-neurons) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_181533-q017i8he</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/q017i8he' target="_blank">radiant-sky-32</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/q017i8he' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/q017i8he</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/usf-alpha-neurons/RNN/runs/q017i8he?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# Load dataset (Weather dataset with temperature and humidity)
# Load the NOAA weather dataset
data = pd.read_csv("/content/USW00014607.csv")


# Display the first few rows of the dataset
print(data.columns)

# Inspect the first few rows of the data to understand its structure
print(data.head())

#data.columns = ['Temperature', 'Humidity']  # Renaming columns for clarity
# Out:
# Index(['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'NAME', 'PRCP',
#        'PRCP_ATTRIBUTES', 'SNOW', 'SNOW_ATTRIBUTES',
#        ...
#        'WT19', 'WT19_ATTRIBUTES', 'WT21', 'WT21_ATTRIBUTES', 'WT22',
#        'WT22_ATTRIBUTES', 'WV03', 'WV03_ATTRIBUTES', 'WV20',
#        'WV20_ATTRIBUTES'],
#       dtype='object', length=144)
#        STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00014607  1939-01-16  46.87049  -68.01723      188.6
# 1  USW00014607  1939-01-17  46.87049  -68.01723      188.6
# 2  USW00014607  1939-01-18  46.87049  -68.01723      188.6
# 3  USW00014607  1939-01-19  46.87049  -68.01723      188.6
# 4  USW00014607  1939-01-20  46.87049  -68.01723      188.6
#
#                                      NAME  PRCP PRCP_ATTRIBUTES  SNOW  \
# 0  CARIBOU WEATHER FORECAST OFFICE, ME US   0.0            ,,0,   NaN
# 1  CARIBOU WEATHER FORECAST OFFICE, ME US   0.0           T,,0,   NaN
# 2  CARIBOU WEATHER FORECAST OFFICE, ME US   0.0           T,,0,   NaN
# 3  CARIBOU WEATHER FORECAST OFFICE, ME US   0.0            ,,0,   NaN
# 4  CARIBOU WEATHER FORECAST OFFICE, ME US   0.0           T,,0,   NaN
#
#   SNOW_ATTRIBUTES  ...  WT19 WT19_ATTRIBUTES  WT21 WT21_ATTRIBUTES  WT22  \
# 0             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 1             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 2             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 3             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 4             NaN  ...   NaN             NaN   NaN             NaN   NaN
#
#   WT22_ATTRIBUTES  WV03 WV03_ATTRIBUTES  WV20 WV20_ATTRIBUTES
# 0             NaN   NaN             NaN   NaN             NaN
# 1             NaN   NaN             NaN   NaN             NaN
# 2             NaN   NaN             NaN   NaN             NaN
# 3             NaN   NaN             NaN   NaN             NaN
# 4             NaN   NaN             NaN   NaN             NaN
#
# [5 rows x 144 columns]
# <ipython-input-9-7123e0c343a5>:3: DtypeWarning: Columns (17,19,21,23,25,27,29,31,33,35,37,39,41,43,45,47,49,51,53,55,57,59,61,63,65,67,69,71,73,75,77,79,81,83,85,87,89,91,93,95,97,101,107,109,111,115,117,119,121,123,125,127,129,131,133,135,137,139,141,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/USW00014607.csv")

# %%
# Select relevant columns (TMAX for temperature, RHAV for humidity)
data = data[['DATE', 'TMAX', 'RHAV']]

# Convert 'DATE' column to datetime type
data['DATE'] = pd.to_datetime(data['DATE'])

# Handle any missing data (you can choose to fill or drop them based on your analysis)
data.dropna(subset=['TMAX', 'RHAV'], inplace=True)

# Visualize the dataset
plt.figure(figsize=(12,6))
plt.plot(data['DATE'], data['TMAX'], label='Max Temperature (TMAX)')
plt.plot(data['DATE'], data['RHAV'], label='Avg Humidity (RHAV)')
plt.title('Temperature and Humidity over Time')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.show()

# Normalize the data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data[['TMAX', 'RHAV']])

# Function to create sequences for the RNN
def create_sequences(data, seq_length=3):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length, 0])  # Predicting Temperature (TMAX) only
    return np.array(X), np.array(y)

SEQ_LENGTH = 3
X, y = create_sequences(data_scaled, SEQ_LENGTH)

# Convert to PyTorch tensors
import torch
from torch.utils.data import DataLoader, TensorDataset

X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

# Split into train and test sets
split = int(0.8 * len(X))
train_dataset = TensorDataset(X_tensor[:split], y_tensor[:split])
test_dataset = TensorDataset(X_tensor[split:], y_tensor[split:])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# <ipython-input-10-70a9e76e957a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DATE'] = pd.to_datetime(data['DATE'])
# <ipython-input-10-70a9e76e957a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(subset=['TMAX', 'RHAV'], inplace=True)

# %%
# Access wandb.config as a dictionary
config = wandb.config

# Assign hyperparameters using dictionary keys
input_size = config['input_size']
hidden_size = config['hidden_size']
output_size = config['output_size']
num_epochs = config['num_epochs']
learning_rate = config['learning_rate']

# Define the RNN model
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.rnn(x)
        out = self.fc(out[:, -1, :])  # Take the last output in the sequence
        return out

# Initialize the model, loss function, and optimizer
model = RNNModel(input_size, hidden_size, output_size)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_losses = []
epochs = []

# Training loop with W&B logging
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0

    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets.view(-1, 1))  # Ensure targets have correct shape
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)

    train_loss /= len(train_loader.dataset)

    # Log training metrics to W&B
    train_losses.append(train_loss)
    epochs.append(epoch + 1)
    wandb.log({'train_loss': train_loss, 'epoch': epoch + 1})

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}')
# Out:
# Epoch [10/10], Loss: 0.0050

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# After training, evaluate the model and log metrics
model.eval()
y_pred = []
y_true = []

with torch.no_grad():
    for inputs, targets in test_loader:
        outputs = model(inputs)
        y_pred.extend(outputs.numpy())
        y_true.extend(targets.numpy())

# Convert predictions and targets to numpy arrays
y_pred = np.array(y_pred).flatten()
y_true = np.array(y_true).flatten()

# Calculate evaluation metrics
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

# Log evaluation metrics to W&B
wandb.log({'mse': mse, 'mae': mae})

print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')

# Visualize predictions vs true values
plt.figure(figsize=(12,6))
plt.plot(range(len(y_true)), y_true, label='True Temperature')
plt.plot(range(len(y_pred)), y_pred, label='Predicted Temperature')
plt.title('True vs Predicted Temperature')
plt.xlabel('Time')
plt.ylabel('Temperature (TMAX)')
plt.legend()

# Log the plot to W&B
wandb.log({"predictions_vs_true_plot": plt})

# Save the model locally first
torch.save(model.state_dict(), 'model.pth')

# Save the model as an artifact in W&B
artifact = wandb.Artifact('temperature-forecasting-model', type='model')
artifact.add_file('model.pth')  # Now it should find the file

# Log the artifact to W&B
wandb.log_artifact(artifact)
# Out:
# Mean Squared Error (MSE): 0.0057
# Mean Absolute Error (MAE): 0.0582
# /usr/local/lib/python3.11/dist-packages/plotly/matplotlylib/renderer.py:609: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.
# <Artifact temperature-forecasting-model>

# %%
# Plot: True vs Predicted Temperature
plt.figure(figsize=(12, 6))
plt.plot(y_true, label='True Temperature (TMAX)', color='blue')
plt.plot(y_pred, label='Predicted Temperature (TMAX)', color='red', linestyle='--')
plt.title('True vs Predicted Temperature over Time')
plt.xlabel('Time')
plt.ylabel('Temperature (TMAX)')
plt.legend(loc='upper right')
plt.grid(True)

# Save the plot to a file
plot_filename = 'true_vs_predicted_plot.png'
plt.savefig(plot_filename)

# Log the image file to W&B
wandb.log({"true_vs_predicted_plot": wandb.Image(plot_filename)})

# Optionally display the plot
plt.show()

# %%
# Plot: Loss vs Epochs
plt.figure(figsize=(12, 6))
plt.plot(epochs, train_losses, label='Training Loss', color='orange')
plt.title('Training Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)

# Save the plot to a file
loss_plot_filename = 'loss_vs_epoch_plot.png'
plt.savefig(loss_plot_filename)

# Log the image file to W&B
wandb.log({"loss_vs_epoch_plot": wandb.Image(loss_plot_filename)})

# Optionally display the plot
plt.show()

# %%
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>mae</td><td>▁</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>mae</td><td>0.0582</td></tr><tr><td>mse</td><td>0.0057</td></tr><tr><td>train_loss</td><td>0.005</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pleasant-pine-3</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/hlsfl2zt' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/hlsfl2zt</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 3 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250330_062606-hlsfl2zt/logs</code>

# %%
# Sample input size
seq_len = 10    # Number of past time steps used for prediction
num_features = 2  # Number of features (e.g., temperature and humidity)
output_size = 1  # Predicting a single value at t+1

class CNN_LSTM(nn.Module):
    def __init__(self):
        super(CNN_LSTM, self).__init__()

        # Convolutional Layer
        self.cnn = nn.Sequential(
            nn.Conv1d(in_channels=num_features, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2)
        )

        # LSTM Layer
        self.lstm = nn.LSTM(input_size=32, hidden_size=64, num_layers=1, batch_first=True)

        # Fully connected layer
        self.fc = nn.Linear(64, output_size)

    def forward(self, x):
        # Permute for CNN layer: (batch_size, num_features, seq_len)
        x = x.permute(0, 2, 1)

        # Apply CNN
        x = self.cnn(x)

        # Permute back for LSTM layer: (batch_size, seq_len, features)
        x = x.permute(0, 2, 1)

        # Apply LSTM
        lstm_out, _ = self.lstm(x)

        # Take the last time step's output for prediction
        out = self.fc(lstm_out[:, -1, :])

        return out


# Instantiate the model, loss function, and optimizer
model = CNN_LSTM()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Log hyperparameters to W&B
wandb.config = {
    "learning_rate": 0.001,
    "epochs": 10,
    "batch_size": 32,
    "model_architecture": "CNN-LSTM",
    "seq_len": seq_len,
    "num_features": num_features
}


# Training loop
epochs = 10
train_losses = []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0

    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()

        # Forward pass
        output = model(X_batch)

        # Compute loss
        loss = criterion(output, y_batch)
        running_loss += loss.item() * X_batch.size(0)

        # Backpropagation and optimization
        loss.backward()
        optimizer.step()

    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)

    # Log metrics to W&B
    wandb.log({"train_loss": epoch_loss, "epoch": epoch + 1})

    if (epoch+1) % 5 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {epoch_loss:.4f}')

# Plot Training Loss
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs+1), train_losses, label='Training Loss', color='orange')
plt.title('Training Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Log the training loss curve to W&B
wandb.log({"Training Loss Curve": wandb.Image(plt)})

# Save the trained model
model_path = "cnn_lstm_model.pth"
torch.save(model.state_dict(), model_path)

# Log the model as an artifact
artifact = wandb.Artifact("cnn_lstm_model", type="model")
artifact.add_file(model_path)
wandb.log_artifact(artifact)
# Out:
# Epoch [5/10], Loss: 0.0392
# Epoch [10/10], Loss: 0.0390
# <Artifact cnn_lstm_model>

# %%
from sklearn.metrics import mean_absolute_error, r2_score
# Testing and Evaluation

model.eval()
y_true = []
y_pred = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        outputs = model(X_batch)
        y_true.extend(y_batch.numpy().flatten())
        y_pred.extend(outputs.numpy().flatten())

# Compute metrics
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
mape = np.mean(np.abs((np.array(y_true) - np.array(y_pred)) / np.array(y_true))) * 100

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R² Score: {r2:.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")

# Log metrics to W&B
wandb.log({
    "MAE": mae,
    "R2": r2,
    "MAPE": mape
})

# Plot Predictions vs True Values
plt.figure(figsize=(12, 6))
plt.plot(y_true[:100], label='True Values', color='blue')
plt.plot(y_pred[:100], label='Predicted Values', color='red')
plt.title('Predictions vs True Values')
plt.xlabel('Samples')
plt.ylabel('Values')
plt.legend()
plt.show()

# Log prediction plot to W&B
wandb.log({"Prediction Plot": wandb.Image(plt)})
# Out:
# Mean Absolute Error (MAE): 0.1675
# R² Score: 0.0263
# Mean Absolute Percentage Error (MAPE): 32.4214%

# %%
# Define your model
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.rnn(x)
        out = self.fc(out[:, -1, :])
        return out

# Define hyperparameters to tune
hyperparameters = {
    "hidden_size": [32, 64, 128],
    "learning_rate": [0.001, 0.0005, 0.0001],
    "num_epochs": [10,15]
}

input_size = 2
output_size = 1

criterion = nn.MSELoss()

# Dataset and DataLoader
# Assuming you have your train_loader and test_loader already defined

for hidden_size in hyperparameters["hidden_size"]:
    for learning_rate in hyperparameters["learning_rate"]:
        for num_epochs in hyperparameters["num_epochs"]:

            # Initialize W&B run
            wandb.init(
                project="RNN", entity="usf-alpha-neurons",
                config={
                    "hidden_size": hidden_size,
                    "learning_rate": learning_rate,
                    "num_epochs": num_epochs
                },
                tags=["manual_tuning", "RNN"],
                name=f"HS-{hidden_size}_LR-{learning_rate}_E-{num_epochs}"
            )

            # Initialize model, optimizer
            model = RNNModel(input_size, hidden_size, output_size)
            optimizer = optim.Adam(model.parameters(), lr=learning_rate)

            for epoch in range(num_epochs):
                model.train()
                train_loss = 0.0

                for inputs, targets in train_loader:
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = criterion(outputs, targets.view(-1, 1))
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item() * inputs.size(0)

                train_loss /= len(train_loader.dataset)

                # Log metrics to W&B
                wandb.log({"train_loss": train_loss, "epoch": epoch + 1})

                if (epoch + 1) % 10 == 0:
                    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}")

            wandb.finish()
# Out:
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190529-8i2dbe9i</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/8i2dbe9i' target="_blank">HS-32_LR-0.001_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/8i2dbe9i' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/8i2dbe9i</a>
# Epoch [10/10], Loss: 0.0051
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.0051</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-32_LR-0.001_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/8i2dbe9i' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/8i2dbe9i</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190529-8i2dbe9i/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190535-6b159ua3</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/6b159ua3' target="_blank">HS-32_LR-0.001_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/6b159ua3' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/6b159ua3</a>
# Epoch [10/15], Loss: 0.0050
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.00495</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-32_LR-0.001_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/6b159ua3' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/6b159ua3</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190535-6b159ua3/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190541-kdqpx4e5</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/kdqpx4e5' target="_blank">HS-32_LR-0.0005_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/kdqpx4e5' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/kdqpx4e5</a>
# Epoch [10/10], Loss: 0.0059
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00587</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-32_LR-0.0005_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/kdqpx4e5' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/kdqpx4e5</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190541-kdqpx4e5/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190546-6o9b9cbs</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/6o9b9cbs' target="_blank">HS-32_LR-0.0005_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/6o9b9cbs' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/6o9b9cbs</a>
# Epoch [10/15], Loss: 0.0059
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.0054</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-32_LR-0.0005_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/6o9b9cbs' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/6o9b9cbs</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190546-6o9b9cbs/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190553-3ek8jmf7</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/3ek8jmf7' target="_blank">HS-32_LR-0.0001_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/3ek8jmf7' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/3ek8jmf7</a>
# Epoch [10/10], Loss: 0.0073
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00734</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-32_LR-0.0001_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/3ek8jmf7' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/3ek8jmf7</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190553-3ek8jmf7/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190558-ns5kf9ol</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/ns5kf9ol' target="_blank">HS-32_LR-0.0001_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/ns5kf9ol' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/ns5kf9ol</a>
# Epoch [10/15], Loss: 0.0070
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.00626</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-32_LR-0.0001_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/ns5kf9ol' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/ns5kf9ol</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190558-ns5kf9ol/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190604-47b56c0b</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/47b56c0b' target="_blank">HS-64_LR-0.001_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/47b56c0b' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/47b56c0b</a>
# Epoch [10/10], Loss: 0.0052
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.0052</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-64_LR-0.001_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/47b56c0b' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/47b56c0b</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190604-47b56c0b/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190609-051e30td</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/051e30td' target="_blank">HS-64_LR-0.001_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/051e30td' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/051e30td</a>
# Epoch [10/15], Loss: 0.0052
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.00508</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-64_LR-0.001_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/051e30td' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/051e30td</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190609-051e30td/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190615-8y660m47</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/8y660m47' target="_blank">HS-64_LR-0.0005_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/8y660m47' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/8y660m47</a>
# Epoch [10/10], Loss: 0.0051
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00515</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-64_LR-0.0005_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/8y660m47' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/8y660m47</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190615-8y660m47/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190620-4sxk5r2c</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/4sxk5r2c' target="_blank">HS-64_LR-0.0005_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/4sxk5r2c' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/4sxk5r2c</a>
# Epoch [10/15], Loss: 0.0053
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.00497</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-64_LR-0.0005_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/4sxk5r2c' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/4sxk5r2c</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190620-4sxk5r2c/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190628-th0hrjwm</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/th0hrjwm' target="_blank">HS-64_LR-0.0001_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/th0hrjwm' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/th0hrjwm</a>
# Epoch [10/10], Loss: 0.0070
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00701</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-64_LR-0.0001_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/th0hrjwm' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/th0hrjwm</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190628-th0hrjwm/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190633-nf9i4elc</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/nf9i4elc' target="_blank">HS-64_LR-0.0001_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/nf9i4elc' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/nf9i4elc</a>
# Epoch [10/15], Loss: 0.0064
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.00606</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-64_LR-0.0001_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/nf9i4elc' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/nf9i4elc</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190633-nf9i4elc/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190640-uuw72zkj</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/uuw72zkj' target="_blank">HS-128_LR-0.001_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/uuw72zkj' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/uuw72zkj</a>
# Epoch [10/10], Loss: 0.0050
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00503</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-128_LR-0.001_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/uuw72zkj' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/uuw72zkj</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190640-uuw72zkj/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190644-je530ux1</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/je530ux1' target="_blank">HS-128_LR-0.001_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/je530ux1' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/je530ux1</a>
# Epoch [10/15], Loss: 0.0051
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.00504</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-128_LR-0.001_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/je530ux1' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/je530ux1</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190644-je530ux1/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190652-v24fem7o</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/v24fem7o' target="_blank">HS-128_LR-0.0005_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/v24fem7o' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/v24fem7o</a>
# Epoch [10/10], Loss: 0.0050
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00501</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-128_LR-0.0005_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/v24fem7o' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/v24fem7o</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190652-v24fem7o/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190657-hpyfd8mt</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/hpyfd8mt' target="_blank">HS-128_LR-0.0005_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/hpyfd8mt' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/hpyfd8mt</a>
# Epoch [10/15], Loss: 0.0052
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.005</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-128_LR-0.0005_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/hpyfd8mt' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/hpyfd8mt</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190657-hpyfd8mt/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190705-1gm0za0b</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/1gm0za0b' target="_blank">HS-128_LR-0.0001_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/1gm0za0b' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/1gm0za0b</a>
# Epoch [10/10], Loss: 0.0067
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00666</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-128_LR-0.0001_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/1gm0za0b' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/1gm0za0b</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190705-1gm0za0b/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_190710-9wo1k5ap</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/9wo1k5ap' target="_blank">HS-128_LR-0.0001_E-15</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/9wo1k5ap' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/9wo1k5ap</a>
# Epoch [10/15], Loss: 0.0066
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_loss</td><td>0.00603</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-128_LR-0.0001_E-15</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/9wo1k5ap' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/9wo1k5ap</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_190710-9wo1k5ap/logs</code>

# %%
# Define your model
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.rnn(x)
        out = self.fc(out[:, -1, :])
        return out

# Define hyperparameters to tune
hyperparameters = {
    "hidden_size": [16,32,64],
    "learning_rate": [0.005, 0.0005],
    "num_epochs": [10]
}

input_size = 2
output_size = 1

criterion = nn.MSELoss()

# Dataset and DataLoader
# Assuming you have your train_loader and test_loader already defined

for hidden_size in hyperparameters["hidden_size"]:
    for learning_rate in hyperparameters["learning_rate"]:
        for num_epochs in hyperparameters["num_epochs"]:

            # Initialize W&B run
            wandb.init(
                project="RNN", entity="usf-alpha-neurons",
                config={
                    "hidden_size": hidden_size,
                    "learning_rate": learning_rate,
                    "num_epochs": num_epochs
                },
                tags=["manual_tuning", "RNN"],
                name=f"HS-{hidden_size}_LR-{learning_rate}_E-{num_epochs}"
            )

            # Initialize model, optimizer
            model = RNNModel(input_size, hidden_size, output_size)
            optimizer = optim.Adam(model.parameters(), lr=learning_rate)

            for epoch in range(num_epochs):
                model.train()
                train_loss = 0.0

                for inputs, targets in train_loader:
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = criterion(outputs, targets.view(-1, 1))
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item() * inputs.size(0)

                train_loss /= len(train_loader.dataset)

                # Log metrics to W&B
                wandb.log({"train_loss": train_loss, "epoch": epoch + 1})

                if (epoch + 1) % 10 == 0:
                    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_loss:.4f}")

            wandb.finish()
# Out:
# Epoch [10/10], Loss: 0.0051
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00509</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">radiant-sky-32</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/q017i8he' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/q017i8he</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_181533-q017i8he/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_181807-r696aw57</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/r696aw57' target="_blank">HS-16_LR-0.0005_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/r696aw57' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/r696aw57</a>
# Epoch [10/10], Loss: 0.0059
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00585</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-16_LR-0.0005_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/r696aw57' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/r696aw57</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_181807-r696aw57/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_181812-hc4xw8b3</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/hc4xw8b3' target="_blank">HS-32_LR-0.005_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/hc4xw8b3' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/hc4xw8b3</a>
# Epoch [10/10], Loss: 0.0051
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.0051</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-32_LR-0.005_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/hc4xw8b3' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/hc4xw8b3</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_181812-hc4xw8b3/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_181817-rxnu6c9v</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/rxnu6c9v' target="_blank">HS-32_LR-0.0005_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/rxnu6c9v' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/rxnu6c9v</a>
# Epoch [10/10], Loss: 0.0054
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.0054</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-32_LR-0.0005_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/rxnu6c9v' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/rxnu6c9v</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_181817-rxnu6c9v/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_181822-bggrb47i</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/bggrb47i' target="_blank">HS-64_LR-0.005_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/bggrb47i' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/bggrb47i</a>
# Epoch [10/10], Loss: 0.0053
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00527</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-64_LR-0.005_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/bggrb47i' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/bggrb47i</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_181822-bggrb47i/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_181828-qhmdh58q</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/qhmdh58q' target="_blank">HS-64_LR-0.0005_E-10</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/qhmdh58q' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/qhmdh58q</a>
# Epoch [10/10], Loss: 0.0053
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.00533</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">HS-64_LR-0.0005_E-10</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/qhmdh58q' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/qhmdh58q</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_181828-qhmdh58q/logs</code>

# %%
wandb.init(project="RNN", entity="usf-alpha-neurons")
save_path = f"HS-64_LR-0.0005_E-15.pth"
torch.save(model.state_dict(), save_path)

# Log the model as an artifact
artifact = wandb.Artifact(
    name=f"RNNmodel_HS-64_LR-0.0005_E15",
    type="model",
    description=f"RNN model with HS= 64, LR= 0.0001, Epochs= 10",
    metadata={  # Store hyperparameters as metadata for easy comparison
        "hidden_size": hidden_size,
        "learning_rate": learning_rate,
        "num_epochs": num_epochs
    }
)
artifact.add_file(save_path)
wandb.log_artifact(artifact)
# Out:
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250331_191122-nir5psdr</code>
# Syncing run <strong><a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/nir5psdr' target="_blank">stellar-sea-55</a></strong> to <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a>
#  View run at <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/nir5psdr' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/nir5psdr</a>
# <Artifact RNNmodel_HS-64_LR-0.0005_E15>

# %%
# Finish the W&B run
wandb.finish()
# Out:
#  View run <strong style="color:#cdcd00">stellar-sea-55</strong> at: <a href='https://wandb.ai/usf-alpha-neurons/RNN/runs/nir5psdr' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN/runs/nir5psdr</a><br> View project at: <a href='https://wandb.ai/usf-alpha-neurons/RNN' target="_blank">https://wandb.ai/usf-alpha-neurons/RNN</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250331_191122-nir5psdr/logs</code>
